# %%
import numpy as np
import pandas as pd

# %%
print(np.__version__)
# Out:
# 1.21.5

# %%
data=pd.read_csv("data1.csv")
print(data.shape[0])
# Out:
# 11914

# %%
print(data[['Make','Popularity']])
# Out:
#           Make  Popularity
# 0          BMW        3916
# 1          BMW        3916
# 2          BMW        3916
# 3          BMW        3916
# 4          BMW        3916
# ...        ...         ...
# 11909    Acura         204
# 11910    Acura         204
# 11911    Acura         204
# 11912    Acura         204
# 11913  Lincoln          61
#
# [11914 rows x 2 columns]

# %%
data=data.filter(items=['Make','Popularity'])
data
# Out:
#           Make  Popularity
# 0          BMW        3916
# 1          BMW        3916
# 2          BMW        3916
# 3          BMW        3916
# 4          BMW        3916
# ...        ...         ...
# 11909    Acura         204
# 11910    Acura         204
# 11911    Acura         204
# 11912    Acura         204
# 11913  Lincoln          61
#
# [11914 rows x 2 columns]

# %%
data=data.loc[(data['Make'].str.contains('Chevrolet', case=False))| (data['Make'].str.contains('Ford', case=False)) | (data['Make'].str.contains('Volkswagen', case=False))| (data['Make'].str.contains('Toyota', case=False))]
print(data)
# Out:
#          Make  Popularity
# 479    Toyota        2031
# 480    Toyota        2031
# 481    Toyota        2031
# 482    Toyota        2031
# 483    Toyota        2031
# ...       ...         ...
# 11827  Toyota        2031
# 11828  Toyota        2031
# 11829  Toyota        2031
# 11830  Toyota        2031
# 11831  Toyota        2031
#
# [3559 rows x 2 columns]

# %%
grouped=data.groupby(['Make']).groups

# %%
print(data.groupby(['Make','Popularity']).size())
# Out:
# Make        Popularity
# Chevrolet   1385          1123
# Ford        5657           881
# Toyota      2031           746
# Volkswagen  873            809
# dtype: int64

# %%
df=pd.read_csv("data1.csv")
df = df.loc[df['Make'].str.contains('Audi')]

# %%
print(len(df.Model.unique()))
# Out:
# 34

# %%
df=pd.read_csv("data1.csv")
x=df.isnull().sum()

c=[i for i in x if i is not 0]
print(len(c))
# Out:
# 5
# <>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\Fresher\AppData\Local\Temp\ipykernel_18232\410324323.py:4: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   c=[i for i in x if i is not 0]

# %%
df["Engine Cylinders"].median()
# Out:
# 6.0

# %%
df["Engine Cylinders"].mode()
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
df["Engine Cylinders"].fillna(df["Engine Cylinders"].mode())
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
df["Engine Cylinders"].median()
# Out:
# 6.0

# %%
for i in range(len(df)):
    if df.iloc[i]["Make"]=="Lotus":
        print(df.iloc[i][["Engine HP","Engine Cylinders"]])
# Out:
# Engine HP           189.0
# Engine Cylinders      4.0
# Name: 3912, dtype: object
# Engine HP           218.0
# Engine Cylinders      4.0
# Name: 3913, dtype: object
# Engine HP           189.0
# Engine Cylinders      4.0
# Name: 3914, dtype: object
# Engine HP           189.0
# Engine Cylinders      4.0
# Name: 3915, dtype: object
# Engine HP           218.0
# Engine Cylinders      4.0
# Name: 3916, dtype: object
# Engine HP           189.0
# Engine Cylinders      4.0
# Name: 3917, dtype: object
# Engine HP           217.0
# Engine Cylinders      4.0
# Name: 3918, dtype: object
# Engine HP           217.0
# Engine Cylinders      4.0
# Name: 3919, dtype: object
# Engine HP           350.0
# Engine Cylinders      8.0
# Name: 4216, dtype: object
# Engine HP           350.0
# Engine Cylinders      8.0
# Name: 4217, dtype: object
# Engine HP           350.0
# Engine Cylinders      8.0
# Name: 4218, dtype: object
# Engine HP           400.0
# Engine Cylinders      6.0
# ...

# %%
val = df[df['Make']=='Lotus'][['Engine HP','Engine Cylinders']]

# %%
x = np.array(val.drop_duplicates())

# %%
xtx = np.dot(x.T , x)
xtx
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
inverted = np.linalg.inv(xtx)

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])

# %%
w = np.dot(np.dot(inverted,x.T),y)

# %%
w[0]
# Out:
# 4.594944810094576

# %%
hi = df.groupby(['Make','Popularity']).sum()

# %%
hi = pd.DataFrame(hi)

# %%
bye = [i[1] for i in hi.index]
bye.remove(5657)

# %%
max(bye)
# Out:
# 3916

# %%
hi
# Out:
#                              Year  Engine HP  Engine Cylinders  \
# Make          Popularity
# Acura         204          506536    61689.0            1344.0
# Alfa Romeo    113           10077     1185.0              20.0
# Aston Martin  259          187211    45042.0             988.0
# Audi          3105         660012    91084.0            1823.0
# BMW           3916         672792   109187.0            1990.0
# Bentley       520          148866    39505.0             720.0
# Bugatti       820            6025     3003.0              48.0
# Buick         155          393961    42972.0            1042.0
# Cadillac      1624         799221   131927.0            2554.0
# Chevrolet     1385        2257328   275868.0            6623.0
# Chrysler      1013         375582    42849.0            1046.0
# Dodge         1851        1255406   153004.0            3918.0
# FIAT          819          124994     8470.0             236.0
# ...

# %%
any(pd.isnull(df["Market Category"]))
# Out:
# True
